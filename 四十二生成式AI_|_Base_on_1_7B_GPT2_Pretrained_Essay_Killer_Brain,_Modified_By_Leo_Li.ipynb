# %% [markdown]
# <a href="https://colab.research.google.com/github/leostudiooo/EssayKiller_V2/blob/master/%E5%9B%9B%E5%8D%81%E4%BA%8C%E7%94%9F%E6%88%90%E5%BC%8FAI_%7C_Base_on_1_7B_GPT2_Pretrained_Essay_Killer_Brain%2C_Modified_By_Leo_Li.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![GitHub stars](https://img.shields.io/github/stars/EssayKillerBrain/EssayKiller?style=social)](https://github.com/imcaspar/gpt2-ml)
# [![GitHub](https://img.shields.io/github/license/EssayKillerBrain/EssayKiller)](https://github.com/imcaspar/gpt2-ml)
# [![Twitter URL](https://img.shields.io/twitter/url?style=social&url=https%3A%2F%2Fgithub.com%2Fimcaspar%2Fgpt2-ml)](https://twitter.com/intent/tweet?text=Wow:&url=https://github.com/imcaspar/gpt2-ml)
# ### 四十二使用指南:
#
# * 点击代码框左上角的▶️* 等待对应代码、模型文件下载
# * 输入参数，代表长度
# * 输入问题，等待AI回答
#
# 之后就会生成对应回答，效果如下:

# %%
#@title #参数与开源框架预加载
# !pip install pandas==0.24.2 &> tmp.log
# !pip install regex==2019.4.14 &> tmp.log
# !pip install h5py==2.10.0 &> tmp.log
# !pip install numpy==1.18.4 &> tmp.log
# !pip install tensorboard==1.15.0 &> tmp.log
# !pip install tensorflow-gpu==1.15.2 &> tmp.log
# !pip install tensorflow-estimator==1.15.1 &> tmp.log
# !pip install tqdm==4.31.1 &> tmp.log
# !pip install requests==2.22.0 &> tmp.log
# !pip install ujson==2.0.3 &> tmp.log
# !echo '预加载模块结束，请继续点击下方的▶️'
#@title #Prerequisites
# Out:
# 预加载模块结束，请继续点击下方的▶️

# %%
#@title #模型框架加载模块
# %cd /home
# !git clone -b master https://github.com/EssayKillerBrain/EssayKiller_V2.git 

#%tensorflow_version 1.5.2-GPU/TPU
# !mkdir -p /home/EssayKiller_V2/LanguageNetwork/GPT2/finetune/trained_models

# %cd /home/EssayKiller_V2/LanguageNetwork/GPT2/finetune/
# !perl /home/EssayKiller_V2/LanguageNetwork/GPT2/scripts/gdown.pl https://drive.google.com/file/d/1A910UqSNBBi_SEoIDl15095T_5kojESO trained_models/model.ckpt-344000.data-00000-of-00001
# !wget -q --show-progress https://github.com/EssayKillerBrain/EssayKiller/releases/download/v1.0/model.ckpt-344000.index -P /home/EssayKiller_V2/LanguageNetwork/GPT2/finetune/trained_models
# !wget -q --show-progress https://github.com/EssayKillerBrain/EssayKiller/releases/download/v1.0/model.ckpt-344000.meta -P /home/EssayKiller_V2/LanguageNetwork/GPT2/finetune/trained_models
# !mv trained_models/model.ckpt-280000.data-00000-of-00001 trained_models/model.ckpt-344000.data-00000-of-00001
# !echo '模型下载完成，Git项目已构建，请继续点击下方的▶️'
# If gdown.pl failed, please uncomment following code & exec
# Out:
# /home
# Cloning into 'EssayKiller_V2'...
# remote: Enumerating objects: 520, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 520 (delta 55), reused 45 (delta 45), pack-reused 439
# Receiving objects: 100% (520/520), 206.35 MiB | 27.08 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
# Checking out files: 100% (274/274), done.
# /home/EssayKiller_V2/LanguageNetwork/GPT2/finetune
# --2022-02-09 10:14:22--  https://docs.google.com/uc?id=1A910UqSNBBi_SEoIDl15095T_5kojESO&export=download
# Resolving docs.google.com (docs.google.com)... 142.251.6.100, 142.251.6.139, 142.251.6.113, ...
# Connecting to docs.google.com (docs.google.com)|142.251.6.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘trained_models/model.ckpt-280000.data-00000-of-00001’
#
#      0K                                     41.2M=0s
#
# 2022-02-09 10:14:22 (41.2 MB/s) - ‘trained_models/model.ckpt-280000.data-00000-of-00001’ saved [3297]
#
# --2022-02-09 10:14:23--  https://docs.google.com/uc?export=download&confirm=wKrd&id=1A910UqSNBBi_SEoIDl15095T_5kojESO
# Resolving docs.google.com (docs.google.com)... 142.251.6.100, 142.251.6.139, 142.251.6.113, ...
# Connecting to docs.google.com (docs.google.com)|142.251.6.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-a4-docs.googleusercontent.com/docs/securesc/814hl2f2apbgba7vh22ke359c82jrfue/g4fgb55i0m1g2hu72lujdnv3bn2v95ie/1644401625000/18027993218153090420/14482678006115550037Z/1A910UqSNBBi_SEoIDl15095T_5kojESO?e=download [following]
# --2022-02-09 10:14:23--  https://doc-00-a4-docs.googleusercontent.com/docs/securesc/814hl2f2apbgba7vh22ke359c82jrfue/g4fgb55i0m1g2hu72lujdnv3bn2v95ie/1644401625000/18027993218153090420/14482678006115550037Z/1A910UqSNBBi_SEoIDl15095T_5kojESO?e=download
# Resolving doc-00-a4-docs.googleusercontent.com (doc-00-a4-docs.googleusercontent.com)... 74.125.132.132, 2607:f8b0:4001:c00::84
# Connecting to doc-00-a4-docs.googleusercontent.com (doc-00-a4-docs.googleusercontent.com)|74.125.132.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=1cmqh5g7h59l0&continue=https://doc-00-a4-docs.googleusercontent.com/docs/securesc/814hl2f2apbgba7vh22ke359c82jrfue/g4fgb55i0m1g2hu72lujdnv3bn2v95ie/1644401625000/18027993218153090420/14482678006115550037Z/1A910UqSNBBi_SEoIDl15095T_5kojESO?e%3Ddownload&hash=m3uln0k4eno3r98srgi144hh77cpfbgj [following]
# --2022-02-09 10:14:23--  https://docs.google.com/nonceSigner?nonce=1cmqh5g7h59l0&continue=https://doc-00-a4-docs.googleusercontent.com/docs/securesc/814hl2f2apbgba7vh22ke359c82jrfue/g4fgb55i0m1g2hu72lujdnv3bn2v95ie/1644401625000/18027993218153090420/14482678006115550037Z/1A910UqSNBBi_SEoIDl15095T_5kojESO?e%3Ddownload&hash=m3uln0k4eno3r98srgi144hh77cpfbgj
# Connecting to docs.google.com (docs.google.com)|142.251.6.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc
# 4816896K ........ ........ ........ ........ 90%  180M 5s
# 4849664K ........ ........ ........ ........ 90%  140M 5s
# 4882432K ........ ........ ........ ........ 91%  130M 4s
# 4915200K ........ ........ ........ ........ 92%  152M 4s
# 4947968K ........ ........ ........ ........ 92%  109M 4s
# 4980736K ........ ........ ........ ........ 93%  139M 3s
# 5013504K ........ ........ ........ ........ 93%  103M 3s
# 5046272K ........ ........ ........ ........ 94%  198M 3s
# 5079040K ........ ........ ........ ........ 95%  132M 2s
# 5111808K ........ ........ ........ ........ 95%  124M 2s
# 5144576K ........ ........ ........ ........ 96%  147M 2s
# 5177344K ........ ........ ........ ........ 96%  102M 2s
# 5210112K ........ ........ ........ ........ 97%  151M 1s
# 5242880K ........ ........ ........ ........ 98% 94.4M 1s
# 5275648K ........ ........ ........ ........ 98%  101M 1s
# 5308416K ........ ........ ........ ........ 99% 73.5M 0s
# 5341184K ........ ........ ........ ........ 99% 90.4M 0s
# 5373952K .                                  100%  216M=50s
#
# 2022-02-09 10:15:13 (106 MB/s) - ‘trained_models/model.ckpt-280000.data-00000-of-00001’ saved [5504439644/5504439644]
#
# model.ckpt-344000.i 100%[===================>]  70.68K  --.-KB/s    in 0.01s
# model.ckpt-344000.m 100%[===================>]  12.44M  --.-KB/s    in 0.1s
# 模型下载完成，Git项目已构建，请继续点击下方的▶️

# %% [markdown]
# ### 模型参数设置:
#
# * 1.回答最小篇幅：
# 生成对应字数的回答，可自己调节长度，最长为1024个汉字。
# 一般来说字数越短，AI表现越好。
#
# * 2.生成回答篇数：
# 默认会生成1篇回答，生成时间取决于服务器状态
# 受限于线上GPU内存，篇数最多为10。

# %%
#!cat /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tpu/tpu_feed.py
#@title #回答生成模块
最小篇幅 = 900 #@param {type:"number", min:800, max:1024, step:1}
生成篇数 = 1 #@param {type:"number", min:1, max:100, step:1}
# %mv /home/EssayKiller_V2/LanguageNetwork/GPT2/finetune/models/mega/* /home/EssayKiller_V2/LanguageNetwork/GPT2/finetune/trained_models/
# %cd /home/EssayKiller_V2/LanguageNetwork/GPT2/

# !echo '模型加载中，请稍后......'
# !PYTHONPATH=$(pwd) python scripts/demo.py -ckpt_fn finetune/trained_models/model.ckpt-344000 -min_len $最小篇幅 -samples $生成篇数
# !PYTHONPATH=$(pwd) python scripts/formatter.py -org_text result.txt
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow_core/python/framework/ops.py", line 5480, in get_controller
#     yield g
#   File "scripts/demo.py", line 223, in <module>
#     text = input()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "scripts/demo.py", line 225, in <module>
#     print("**********************************************新的问题**********************************************\n")
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow_core/python/client/session.py", line 1633, in __exit__
#     close_thread.start()
#   File "/usr/lib/python3.7/threading.py", line 857, in start
#     self._started.wait()
#   File "/usr/lib/python3.7/threading.py", line 552, in wait
#     signaled = self._cond.wait(timeout)
#   File "/usr/lib/python3.7/threading.py", line 296, in wait
#     waiter.acquire()
# KeyboardInterrupt
# the lens:  13
# Traceback (most recent call last):
#   File "scripts/formatter.py", line 132, in <module>
#     with open(args.org_text, 'r',encoding='UTF-8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'result.txt'
